# %% [markdown]
# <a href="https://colab.research.google.com/github/Netesh5/Machine_Learning/blob/main/Matlabplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3]
y=[3,1,2]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
plt.plot(x,y,color="green",marker="o",
         linestyle="dashed",linewidth=3)
plt.title("2D Line Plot")
plt.show()

# %%
x=[5,2,9,4,7]
y=[10,20,30,40,50]
tick_label=["One","Two","Three","Four","Five"]
plt.bar(left,height,tick_label=tick_label,width=0.8,color=["blue","green","red","yellow","black"])
plt.xlabel("x-axis")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-99d730238b61> in <module>
#       2 y=[10,20,30,40,50]
#       3 tick_label=["One","Two","Three","Four","Five"]
# ----> 4 plt.bar(left,height,tick_label=tick_label,width=0.8,color=["blue","green","red","yellow","black"])
#
# NameError: name 'left' is not defined
